# %%
from matplotlib import pyplot as plt
import numpy as np
import torch as tr
from torch import nn
import pandas as pd
# from torch.utils.tensorboard import SummaryWriter
import csv

import os 
import csv

# %%
secdist = pd.read_csv('RNA_dist/data/SequenceIdentity_f_all.csv')
secdist
# Out:
#                                                      id  \
# 0                           5s_Acholeplasma-laidlawii-1
# 1                             5s_Acidovorax-temperans-1
# 2                      tmRNA_Stre.gord._TRW-29390_1-349
# 3     tRNA_tdbR00000055-Schizosaccharomyces_pombe-48...
# 4                                 srp_List.mono._U15684
# ...                                                 ...
# 3970                               5s_Bacillus-cereus-6
# 3971                            srp_Myco.aviu._AE016958
# 3972                    tmRNA_Heli.pylo._AE001503_1-383
# 3973                             5s_Triticum-aestivum-1
# 3974                        5s_Streptomyces-violaceus-1
#
#       5s_Acholeplasma-laidlawii-1  5s_Acidovorax-temperans-1  \
# 0                        1.000000                   0.513043
# 1                        0.513043                   1.000000
# 2                        0.094556                   0.088825
# 3                        0.169643                   0.182609
# 4                        0.093190                   0.139785
# ...                           ...                        ...
# 3970                     0.589744                   0.491525
# 3971                     0.114094                   0.217391
# 3972                     0.096606                   0.096606
# 3973                     0.404959                   0.295082
# 3974                     0.450000                   0.466667
#
#       tmRNA_Stre.gord._TRW-29390_1-349  \
# 0                             0.094556
# 1                             0.088825
# 2                             1.000000
# 3                             0.071633
# 4                             0.206304
# ...                                ...
# 3970                          0.072626
# 3971                          0.057307
# 3972                          0.269430
# 3973                          0.085960
# 3974                          0.117479
#
#       tRNA_tdbR00000055-Schizosaccharomyces_pombe-4896-Glu-3UC  \
# 0                                              0.169643
# 1                                              0.182609
# 2                                              0.071633
# 3                                              1.000000
# 4                                              0.064516
# ...                                                 ...
# 3970                                           0.034091
# 3971                                           0.185185
# 3972                                           0.069948
# 3973                                           0.194030
# 3974                                           0.233333
#
#       srp_List.mono._U15684  5s_Methanothermobacter-thermautotrophicus-6  \
# 0                  0.093190                                     0.406250
# 1                  0.139785                                     0.173611
# 2                  0.206304                                     0.042079
# 3                  0.064516                                     0.154930
# 4                  1.000000                                     0.060000
# ...                     ...                                          ...
# 3970               0.107527                                     0.468750
# 3971               0.089606                                     0.104938
# 3972               0.067797                                     0.080940
# 3973               0.083333                                     0.124260
# 3974               0.081505                                     0.234375
#
#       srp_Vibr.fisc._CP000020  srp_Baci.thur._D11412  \
# 0                    0.143750               0.065421
# 1                    0.094972               0.068750
# 2                    0.111748               0.030769
# 3                    0.243243               0.095941
# 4                    0.204301               0.539007
# ...                       ...                    ...
# 3970                 0.088083               0.118081
# 3971                 0.216216               0.114391
# 3972                 0.083551               0.025890
# 3973                 0.049505               0.114391
# 3974                 0.233333               0.118081
#
#       grp1_a.I1.m.M.grisea.B2.ND1  ...  RNaseP_M.avium  \
# 0                        0.136842  ...        0.072115
# 1                        0.119298  ...        0.090452
# 2                        0.090543  ...        0.092628
# 3                        0.073684  ...        0.060302
# 4                        0.181818  ...        0.183417
# ...                           ...  ...             ...
# 3970                     0.101754  ...        0.025806
# 3971                     0.070175  ...        0.072864
# 3972                     0.064799  ...        0.061256
# 3973                     0.035912  ...        0.108040
# 3974                     0.077193  ...        0.125628
#
#       tRNA_tdbR00000521-Bos_taurus-9913-Ini-CAU  \
# 0                                      0.120000
# 1                                      0.171429
# 2                                      0.074499
# 3                                      0.154639
# 4                                      0.086022
# ...                                         ...
# 3970                                   0.166667
# 3971                                   0.184466
# 3972                                   0.054830
# 3973                                   0.175000
# 3974                                   0.133333
#
#       grp1_a.I1.e.P.pachydermus.C1.SSU.943  5s_Pseudomonas-stutzeri-2  \
# 0                                 0.086735                   0.491667
# 1                                 0.096939                   0.735537
# 2                                 0.142285                   0.114613
# 3                                 0.051020                   0.175000
# 4                                 0.072835                   0.119298
# ...                                    ...                        ...
# 3970                              0.060185                   0.366667
# 3971                              0.073980                   0.266667
# 3972                              0.152000                   0.080940
# 3973                              0.102041                   0.380165
# 3974                              0.045662                   0.586777
#
#       16s_T.maritima_domain3  5s_Bacillus-cereus-6  srp_Myco.aviu._AE016958  \
# 0                   0.064039              0.589744                 0.114094
# 1                   0.055024              0.491525                 0.217391
# 2                   0.123791              0.072626                 0.057307
# 3                   0.056650              0.034091                 0.185185
# 4                   0.039867              0.107527                 0.089606
# ...                      ...                   ...                      ...
# 3970                0.088670              1.000000                 0.083871
# 3971                0.078818              0.083871                 1.000000
# 3972                0.026279              0.104439                 0.075718
# 3973                0.108374              0.421488                 0.114504
# 3974                0.048832              0.491667                 0.227642
#
#       tmRNA_Heli.pylo._AE001503_1-383  5s_Triticum-aestivum-1  \
# 0                            0.096606                0.404959
# 1                            0.096606                0.295082
# 2                            0.269430                0.085960
# 3                            0.069948                0.194030
# 4                            0.067797                0.083333
# ...                               ...                     ...
# 3970                         0.104439                0.421488
# 3971                         0.075718                0.114504
# 3972                         1.000000                0.067885
# 3973                         0.067885                1.000000
# 3974                         0.093995                0.205298
#
#       5s_Streptomyces-violaceus-1
# 0                        0.450000
# 1                        0.466667
# 2                        0.117479
# 3                        0.233333
# 4                        0.081505
# ...                           ...
# 3970                     0.491667
# 3971                     0.227642
# 3972                     0.093995
# 3973                     0.205298
# 3974                     1.000000
#
# [3975 rows x 3976 columns]

# %%
medioides = pd.read_csv('RNA_dist/medioides.csv')

# %%
def file_opener(file_name):
    data_set=[]
    with open(file_name, newline = '') as data:                                                                                         
        data_reader = csv.reader(data, delimiter=',')
        for dat in data_reader:
            data_set.append(dat)
    return data_set
data_set=file_opener('data/archiveII_220808.csv')

# %%
data_set=np.array(data_set)
# data_set = np.array([data_set[1:][:,1],data_set[1:][:,3],data_set[1:][:,4]])
sdasdasd=data_set[1:]
sdasdasd[0][1]
# Out:
# '5s_Acholeplasma-laidlawii-1'

# %% [markdown]
# ### utils

# %%
def seq_to_pair(seq):
    seq_np=list(seq)
    seq_open=[]
    pairs=[]
    for it,char in enumerate(seq_np):
        if (char=='('):
            seq_open.append(it+1)
        if (char==')'):
            pairs.append([seq_open[-1],it+1])
            seq_open=seq_open[:-1]
    pairs=pairs[::-1]
    # pairs=', '.join(str(e) for e in pairs)
    # pairs='['+pairs+']'
    return pairs


def replace_E(seq):
    str=list(seq)
    for it in range(len(str)):
        print(str[it])
        if(str[it]=='('):
            break    
        else:
            str[it]='-'
    print('SALIO')
    for it in range(len(str)-1,0,-1):
        if(str[it]==')'):
            break   
        else:
            str[it]='-'
    return str
    
    
def dot_to_motif(seq, struct):
    """Get motifs from dot-bracket notation structure. Requieres bpRNA.pl script"""

    with open('tmp.dbn', 'w') as fout:
        fout.write('>id\n')
        fout.write(f'{seq}\n')
        fout.write(f'{struct}\n')
        
    os.system('perl extras/bpRNA.pl tmp.dbn')
    with open('tmp.st') as fin:
        k = 0
        for line in fin:
            if line[0] == '#':
                continue
            if k == 2:
                motif = line.strip()
                break
            else:
                k += 1
    os.remove('tmp.dbn')
    os.remove('tmp.st')
    return motif

def seq_len(seq):
   lenght=len(list(seq))
   return lenght

def make_data_set(data_set):
    data=[['id','sequence','structure','base_pairs','len']]
    for i in data_set[1:]:
        if seq_len(i[3]) < 130:
            data.append([i[1],i[3],i[4],seq_to_pair(i[4]),seq_len(i[3])])
      

        # data=data+i[0]+',SOLUTION NMR,'+i[1]+','+i[2]+','+'"'+pair+'"'+','+str(lenght)+'\n'
    writer=pd.DataFrame(data)
    writer.to_csv('dist01.csv',sep=',',header=False,index=False)
    return data

def valid_mask(seq):
    """Create a NxN mask with valid canonic pairings."""
    valid_pairs = [{"G", "C"}, {"A", "U"}, {"G", "U"}]
    mask = tr.zeros((len(seq), len(seq)), dtype=tr.float32)
    for i in range(len(seq)):
        for j in range(len(seq)):
            if i != j:
                if {seq[i], seq[j]} in valid_pairs:
                    mask[i, j] = 1
                    mask[j, i] = 1
    return mask

# %%
data=make_data_set(data_set)

# %%
class OneHot():
    def __init__(self):
        self.pad_token = "-"
        self.vocabulary = ['A', 'U', 'G', 'C'] 
        self.emb_size = 4
        
    def seq2onehot(self, seq):
        emb = tr.zeros((self.emb_size, len(seq)), dtype=tr.float)
        for k, nt in enumerate(seq):
            # print(f'letra = {nt} indice = {k}')
            if nt == self.pad_token:
                continue
            if nt in self.vocabulary:
                emb[self.vocabulary.index(nt), k] = 1
            else:
                emb[:, k] = 1/self.emb_size
            # print(f'embedding = {emb}')
        return emb

# %%
class Data_dist(Dataset):

    def __init__(self,dataset_path, min_len=0, max_len=800,padding=True,random_pad=False):
        dat=pd.read_csv(dataset_path,index_col=None)
        dat = dat[(dat.len > min_len) & (dat.len < max_len)]
        self.lenght=dat.len
        self.max_len=max_len
        self.id=dat.id
        self.seq=dat.sequence
        self.struct=dat.structure
        self.pair=[json.loads(dat.base_pairs.iloc[i]) for i in range(len(dat))]
        self.n_samples=dat.shape[0]
        self.padding = padding
        self.pad_token = '-'
        self.random_pad = random_pad
        self.embedding = OneHot()

    def __getitem__(self,index):
        id = self.id.iloc[index]
        len_seq = len(self.seq.iloc[index])
        connections = tr.tensor(self.pair[index]) -1
        sequence,Mc = self.pad_sequence(self.seq.iloc[index],connections)
        seq_emb=self.embedding.seq2onehot(sequence)
        mask = valid_mask(sequence)
        return seq_emb,Mc,len_seq,mask,id
    def __len__(self): 
        return self.n_samples

        
    def pad_sequence(self, sequence, connections):
        """Pad sequence and create connection matrix to max length"""
        left_pad, right_pad = 0, 0 
        if self.padding:
            left_pad = 0
            right_pad = self.max_len - len(sequence)
            if self.random_pad:
                left_pad = np.random.randint(right_pad)
                right_pad -= left_pad


        sequence = self.pad_token*left_pad + sequence + self.pad_token*right_pad
        # Conection matrix: -1 padding, 0 is not connected, 1 is connected
        Mc = -tr.ones((len(sequence), len(sequence)), dtype=tr.float32)      
        if right_pad > 0:
            Mc[left_pad:-right_pad, left_pad:-right_pad] = 0
        else:
            Mc[left_pad:, left_pad:] = 0

        if len(connections)>0:
            # for i in range(len(connections)):
            #     Mc[connections[][0] + left_pad, connections[i][1] + left_pad] = 1
            Mc[connections[:,0] + left_pad, connections[:,1] + left_pad] = 1
            Mc[connections[:,1] + left_pad, connections[:,0] + left_pad] = 1
        else:
            print(f"Warning: sequence {sequence} do not have any connections")
        return sequence, Mc.long()

# %%
from matplotlib import pyplot as plt

dataset=Data_dist('dist01.csv')
sequence=dataset.seq
L = len(sequence)
seq_emb,mc,long,mask,id=dataset.__getitem__(3)

id
# Out:
# '5s_Methanothermobacter-thermautotrophicus-6'

# %% [markdown]
# # Metricas

# %%
from sklearn.metrics import f1_score
#se suele usar f1 score para todo lo que sean matrices?????????!
def get_f1(ref_batch,predict_batch,L,th=0.5):
    f1 = []
    for ref,predict,l in zip(ref_batch,predict_batch,L):
        ind = tr.where(ref!=-1)
        ref = ref[ind].view(l, l)
        predict = predict[ind].view(l, l)

        #esto si no lo entiendo
        predict = tr.sigmoid(predict) > th

        #parte para tener la matriz triangular superior
        ind = tr.triu_indices(ref.shape[0], ref.shape[1], offset=1)
        ref = ref[ind[0], ind[1]].numpy().ravel()
        predict = predict[ind[0], ind[1]].numpy().ravel()
        f1.append(f1_score(ref, predict, zero_division=1))
    return tr.tensor(f1).mean()

# %% [markdown]
# # Modelo

# %%
class ignacioDist(nn.Module):
    def __init__(self, embedding_dim=4, device="cpu", negative_weight=.1, lr=1e-3, 
    logger=None, pred_l1=.01, use_scheduler=False, **kwargs):
        super().__init__()
        self.device=device
        #por que espesificamente el adam
        #para luego escalar de 0 a 1 el crossentropy
        self.class_weight = tr.tensor([negative_weight, 1.]).float().to(device)
        self.build_graph(embedding_dim, **kwargs)
        self.optim =  tr.optim.Adam(self.parameters(), lr=lr)

        self.to(device)


    
    def build_graph (self,emb_dim,kernel=9,filters=50,rank=32):
        pad = (kernel-1)//2
        dilation = 4
        self.cnn = nn.Sequential(nn.Conv1d(in_channels=emb_dim, out_channels=filters, 
                                        kernel_size=kernel, padding = pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters, 
                                        kernel_size=kernel, dilation = dilation,
                                        padding=dilation*pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters, 
                                        kernel_size=kernel, dilation = dilation,
                                        padding=dilation*pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters//2, 
                                        kernel_size=kernel, padding = pad, stride=1),
                                nn.Sigmoid(),)  
        self.convsal1 = nn.Conv1d(in_channels=filters//2, out_channels=rank, kernel_size=kernel, 
                                  padding=pad, stride=1)
        self.convsal2 = nn.Conv1d(in_channels=filters//2,  out_channels=rank, kernel_size=kernel,
                                  padding = pad, stride=1)

    def forward (self,x):
        n = x.shape[2]
        y = self.cnn(x)
    
        ya = self.convsal1(y)
        ya = tr.transpose(ya, -1, -2)

        yb = self.convsal2(y)
        
        y = ya @ yb
        yt =  tr.transpose(y, -1, -2)
        
        y = (y+yt)/2
    
        #por que pone vectores adentro de otro vectores
        y = y.view(-1, n, n)
        return y
#loss and optim
    def loss_func(self,yt,y):

        #devuelta lo mismo
        y = y.view(y.shape[0], -1)
        yt = yt.view(yt.shape[0], -1)

        #no es la diferencia?
        pred_l1_loss =  tr.mean(tr.abs(yt[y!=-1])) * 0.01 


        #por que no usar devuelta view
        yt = yt.unsqueeze(1)
        #hizo algo el codigo anterior desp de esto? tipo no se deshizo?
        yt = tr.cat((-yt, yt), dim=1) 
        error = cross_entropy(yt, y, ignore_index=-1, weight=self.class_weight)
        loss= error + pred_l1_loss
        return loss
    
    def tr(self,data_loader):
        self.train()
        avg_loss=0
        avg_f1 = 0
        train_step = 0
        for batch in data_loader:
            x = batch[0].to(self.device)
            y = batch[1].to(self.device)
            self.optim.zero_grad()  
            y_tr = self.forward(x)
        
            loss = self.loss_func(y_tr,y)
            f1 = get_f1(y.cpu(), y_tr.detach().cpu(), batch[2])
            avg_f1 += f1
            avg_loss += loss
            loss.backward() 
            self.optim.step()
            train_step+=1

        avg_f1 /= len(data_loader)
        avg_loss /= len(data_loader)
        return avg_loss,avg_f1
    def tst(self,data_loader):
        self.eval() 
        avg_loss=0
        avg_f1=0
        test_step = 0
        #desactivamos el gradiente por que no hacemos backward()
        with tr.no_grad():       
            for batch in data_loader:
                x = batch[0].to(self.device)
                y = batch[1].to(self.device)
                #por que aca y no desp
                y_tst = self.forward(x)
                # y_tst=tr.tensor([[x], *batch[2:]])
                loss = self.loss_func(y_tst,y)
                #.detach()?????????
                f1 = get_f1(y.cpu(), y_tst.detach().cpu(), batch[2])
                avg_loss += loss
                avg_f1 += f1
                test_step+=1
            avg_loss /= len(data_loader)
            avg_f1 /= len(data_loader)
            
            return avg_loss,avg_f1

# %% [markdown]
# # main

# %%
import torch as tr
from torch.utils.data import DataLoader, random_split

out_path = f"results/"
batch_size = 8   
DEVICE = "cuda" 
model = ignacioDist(kernel=11, device=DEVICE) 
# model.load_state_dict(tr.load(f"{out_path}model_200len.pmt"))
dataset=Data_dist('dist03.csv',max_len=130)



n_train = int(0.8 * len(dataset))
n_test = int(0.1 * len(dataset))
n_val = len(dataset) - n_train - n_test



train_data, val_data, test_data = random_split(dataset, [n_train, n_val, n_test], generator=tr.Generator().manual_seed(42))
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

print("train batches", len(train_loader))
print("val batches", len(val_loader))
print("test batches", len(test_loader))
best_f1, patience_counter = 0, 0
for epoch in range(250):
    train_loss,train_f1 = model.tr(train_loader)
    print(f'train loop epoch {epoch}')
    val_loss,val_f1 = model.tst(val_loader)
    if val_f1 > best_f1:
        best_f1 = val_f1
        best_epoch = epoch
        tr.save(model.state_dict(), f"{out_path}model_130len_dist2.pmt")
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter>50:
            break
    print(f"epoch {epoch}: train loss {train_loss:.2f} val loss {val_loss:.2f} train f1 {train_f1:.2f} val f1 {val_f1:.2f}")
print("Start test")
model.load_state_dict(tr.load(f"{out_path}model_130len_dist2.pmt"))
test_loss, test_f1 = model.tst(test_loader)
print(f"best epoch {best_epoch} best_valf1 {best_f1:.3f} test_loss {test_loss:.3f} test_f1 {test_f1:.3f}")
# Out:
# train batches 233
# val batches 30
# test batches 30
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 0
# epoch 0: train loss 0.13 val loss 0.08 train f1 0.27 val f1 0.50
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 1
# epoch 1: train loss 0.07 val loss 0.06 train f1 0.56 val f1 0.60
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 2
# epoch 2: train loss 0.06 val loss 0.06 train f1 0.66 val f1 0.64
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 3
# epoch 3: train loss 0.05 val loss 0.05 train f1 0.77 val f1 0.82
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 4
# epoch 4: train loss 0.05 val loss 0.05 train f1 0.85 val f1 0.85
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 5
# epoch 5: train loss 0.04 val loss 0.05 train f1 0.89 val f1 0.91
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 6
# epoch 6: train loss 0.04 val loss 0.04 train f1 0.92 val f1 0.91
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 7
# epoch 7: train loss 0.04 val loss 0.04 train f1 0.93 val f1 0.92
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 8
# epoch 8: train loss 0.04 val loss 0.04 train f1 0.94 val f1 0.92
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 9
# epoch 9: train loss 0.04 val loss 0.04 train f1 0.95 val f1 0.93
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 10
# epoch 10: train loss 0.04 val loss 0.04 train f1 0.95 val f1 0.94
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 11
# epoch 11: train loss 0.04 val loss 0.04 train f1 0.96 val f1 0.94
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 12
# epoch 12: train loss 0.04 val loss 0.04 train f1 0.96 val f1 0.93
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 13
# epoch 13: train loss 0.04 val loss 0.04 train f1 0.96 val f1 0.94
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 14
# epoch 14: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 15
# epoch 15: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 16
# epoch 16: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 17
# epoch 17: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 18
# epoch 18: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 19
# epoch 19: train loss 0.04 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 20
# epoch 20: train loss 0.03 val loss 0.04 train f1 0.97 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 21
# epoch 21: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.95
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 22
# epoch 22: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 23
# epoch 23: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 24
# epoch 24: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 25
# epoch 25: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 26
# epoch 26: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 27
# epoch 27: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 28
# epoch 28: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.95
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 29
# epoch 29: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 30
# epoch 30: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 31
# epoch 31: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 32
# epoch 32: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 33
# epoch 33: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 34
# epoch 34: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 35
# epoch 35: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 36
# epoch 36: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 37
# epoch 37: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 38
# epoch 38: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 39
# epoch 39: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 40
# epoch 40: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 41
# epoch 41: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 42
# epoch 42: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 43
# epoch 43: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 44
# epoch 44: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 45
# epoch 45: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 46
# epoch 46: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 47
# epoch 47: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 48
# epoch 48: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 49
# epoch 49: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 50
# epoch 50: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 51
# epoch 51: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 52
# epoch 52: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 53
# epoch 53: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 54
# epoch 54: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 55
# epoch 55: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 56
# epoch 56: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 57
# epoch 57: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# train loop epoch 58
# epoch 58: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 59
# epoch 59: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 60
# epoch 60: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 61
# epoch 61: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 62
# epoch 62: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 63
# epoch 63: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.95
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 64
# epoch 64: train loss 0.03 val loss 0.04 train f1 0.98 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGAUUUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# train loop epoch 65
# epoch 65: train loss 0.03 val loss 0.04 train f1 0.99 val f1 0.96
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# Warning: sequence AAACAAUGCACAUCACUACCGGGUCUUGGGCAGUGCGAUAGCGAUGGGAUUCACCUUCGCAGGAUGUGCAUGGAAGUAUAAACACAACGGUCGUU----------------------------------- do not have any connections
# Warning: sequence UGGACCAGCGAGGGUGUUCUGCUGCGUUGACGUGGUGCUCUGCUUGGCUGUGUGUCGG------------------------------------------------------------------------ do not have any connections
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 29
#      27 best_f1, patience_counter = 0, 0
#      28 for epoch in range(250):
# ---> 29     train_loss,train_f1 = model.tr(train_loader)
#      30     print(f'train loop epoch {epoch}')
#      31     val_loss,val_f1 = model.tst(val_loader)
#
# Cell In[18], line 82, in ignacioDist.tr(self, data_loader)
#      80 avg_f1 = 0
#      81 train_step = 0
# ---> 82 for batch in data_loader:
#      83     x = batch[0].to(self.device)
#      84     y = batch[1].to(self.device)
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/torch/utils/data/dataloader.py:671, in _SingleProcessDataLoaderIter._next_data(self)
#     669 def _next_data(self):
#     670     index = self._next_index()  # may raise StopIteration
# --> 671     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     672     if self._pin_memory:
#     673         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:58, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:58, in <listcomp>(.0)
#      56         data = self.dataset.__getitems__(possibly_batched_index)
#      57     else:
# ---> 58         data = [self.dataset[idx] for idx in possibly_batched_index]
#      59 else:
#      60     data = self.dataset[possibly_batched_index]
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/torch/utils/data/dataset.py:295, in Subset.__getitem__(self, idx)
#     293 if isinstance(idx, list):
#     294     return self.dataset[[self.indices[i] for i in idx]]
# --> 295 return self.dataset[self.indices[idx]]
#
# Cell In[15], line 24, in Data_dist.__getitem__(self, index)
#      22 sequence,Mc = self.pad_sequence(self.seq.iloc[index],connections)
#      23 seq_emb=self.embedding.seq2onehot(sequence)
# ---> 24 mask = valid_mask(sequence)
#      25 return seq_emb,Mc,len_seq,mask,id
#
# Cell In[11], line 82, in valid_mask(seq)
#      80             if {seq[i], seq[j]} in valid_pairs:
#      81                 mask[i, j] = 1
# ---> 82                 mask[j, i] = 1
#      83 return mask
#
# KeyboardInterrupt:

# %% [markdown]
# nvidia-smi -l 5

# %%
print("Start test")
model.load_state_dict(tr.load(f"{out_path}model_130len_dist.pmt"))
test_loss, test_f1 = model.tst(test_loader)
print(f"best epoch {best_epoch} best_valf1 {best_f1:.3f} test_loss {test_loss:.3f} test_f1 {test_f1:.3f}")
# Out:
# Start test
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("Start test")
# ----> 2 model.load_state_dict(tr.load(f"{out_path}model_130len_dist.pmt"))
#       3 test_loss, test_f1 = model.tst(test_loader)
#       4 print(f"best epoch {best_epoch} best_valf1 {best_f1:.3f} test_loss {test_loss:.3f} test_f1 {test_f1:.3f}")
#
# NameError: name 'model' is not defined
