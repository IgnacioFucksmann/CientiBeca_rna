# %%
from matplotlib import pyplot as plt
import numpy as np
import torch as tr
from torch import nn
import pandas as pd
import csv
from draw_rna.draw_utils import seq2col
from torch.utils.data import Dataset, DataLoader
from torch.nn.functional import cross_entropy
from embeddings import OneHot

# %%
medioides = pd.read_csv('RNA_dist/medioide.csv')

# %%
def file_opener(file_name):
    data_set=[]
    with open(file_name, newline = '') as data:                                                                                         
        data_reader = csv.reader(data, delimiter=',')
        for dat in data_reader:
            data_set.append(dat)
    return data_set
data_set=file_opener('data/archiveII_220808.csv')

# %% [markdown]
# # Metricas

# %%
from sklearn.metrics import f1_score
#se suele usar f1 score para todo lo que sean matrices?????????!
def get_f1(ref_batch,predict_batch,L,th=0.5):
    f1 = []
    for ref,predict,l in zip(ref_batch,predict_batch,L):
        ind = tr.where(ref!=-1)
        ref = ref[ind].view(l, l)
        predict = predict[ind].view(l, l)

        #esto si no lo entiendo
        predict = tr.sigmoid(predict) > th

        #parte para tener la matriz triangular superior
        ind = tr.triu_indices(ref.shape[0], ref.shape[1], offset=1)
        ref = ref[ind[0], ind[1]].numpy().ravel()
        predict = predict[ind[0], ind[1]].numpy().ravel()
        f1.append(f1_score(ref, predict, zero_division=1))
    return tr.tensor(f1).mean()

# %%
def cluster_score(id,medioides):
    offset_fulldat = tr.empty(len(id),len(medioides))
    cluster_offset=tr.empty(len(medioides))
    
    for i in range(len(id)):
        for j in range(len(medioides)):
            cluster_offset[j]=(secdist[id[i]].loc[medioides.iloc[j][0]])
        offset_fulldat[i]=cluster_offset
    return offset_fulldat


def concatenate_data (offset_list,sec_data,device):
    offset_list=offset_list.int()
    return tr.cat((tr.flatten(sec_data,start_dim=1),offset_list.clone().detach().to(device)),dim=1).to(device)

# %% [markdown]
# # Modelo

# %%
class ignacioDist(nn.Module):
    def __init__(self, embedding_dim=4, device="cpu", negative_weight=.1, lr=1e-3, 
    logger=None, pred_l1=.01, use_scheduler=False,offset=30,max_len=200, **kwargs):
        super().__init__()
        self.device=device
        self.k = offset
        self.len=max_len
        # self.rank = rank
        #por que espesificamente el adam
        #para luego escalar de 0 a 1 el crossentropy
        self.class_weight = tr.tensor([negative_weight, 1.]).float().to(device)
        self.build_graph(embedding_dim,**kwargs)
        self.optim =  tr.optim.Adam(self.parameters(), lr=lr)

        self.to(device)


    
    def build_graph (self,emb_dim,kernel=9,filters=50,rank=32):
        pad = (kernel-1)//2
        dilation = 4
        self.cnn = nn.Sequential(nn.Conv1d(in_channels=emb_dim, out_channels=filters, 
                                        kernel_size=kernel, padding = pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters, 
                                        kernel_size=kernel, dilation = dilation,
                                        padding=dilation*pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters, 
                                        kernel_size=kernel, dilation = dilation,
                                        padding=dilation*pad, stride=1),
                                nn.ReLU(),
                                nn.BatchNorm1d(filters),
                                nn.Conv1d(in_channels=filters, out_channels=filters//2, 
                                        kernel_size=kernel, padding = pad, stride=1),
                                nn.Sigmoid(),)  
        
        self.convsal1 = nn.Conv1d(in_channels=filters//2, out_channels=rank, kernel_size=kernel, 
                                  padding=pad, stride=1)
        self.convsal2 = nn.Conv1d(in_channels=filters//2,  out_channels=rank, kernel_size=kernel,
                                  padding = pad, stride=1)
        self.linear1 = nn.Sequential(nn.Flatten(),
                                    nn.Sigmoid(),
                                    nn.Linear(in_features=(self.len*rank)+ self.k, out_features=(self.len*rank),bias=False)
                                    )
        self.linear2 = nn.Sequential(nn.Flatten(),
                                    nn.Sigmoid(),
                                    nn.Linear(in_features=(self.len*rank)+ self.k, out_features=(self.len*rank),bias=False)
                                    )

    def forward (self,x,id_list,famhot):
        n = x.shape[2]
        y = self.cnn(x)

    
        ya = self.convsal1(y)
        
        yb = self.convsal2(y)

        #concatena el oneHot de cada familia.
        ya = concatenate_data(famhot,ya,self.device)
        yb = concatenate_data(famhot,yb,self.device)

        ya = self.linear1(ya)
        yb = self.linear2(yb)

        
        ya = ya.view(y.shape[0],32,n)
        yb = yb.view(y.shape[0],32,n)
        
        ya = tr.transpose(ya, -1, -2)

        y = ya @ yb

        yt =  tr.transpose(y, -1, -2)
        
        y = (y+yt)/2

        y = y.view(-1, n, n)
        return y
#loss and optim
    def loss_func(self,yt,y):

        #devuelta lo mismo
        y = y.view(y.shape[0], -1)
        yt = yt.view(yt.shape[0], -1)

        #no es la diferencia?
        pred_l1_loss =  tr.mean(tr.abs(yt[y!=-1])) * 0.01 


        #por que no usar devuelta view
        yt = yt.unsqueeze(1)
        #hizo algo el codigo anterior desp de esto? tipo no se deshizo?
        yt = tr.cat((-yt, yt), dim=1) 
        error = cross_entropy(yt, y, ignore_index=-1, weight=self.class_weight)
        loss= error + pred_l1_loss
        return loss
    
    def tr(self,data_loader):
        self.train()
        avg_loss=0
        avg_f1 = 0
        train_step = 0
        for batch in data_loader:
            x = batch[0].to(self.device)
            y = batch[1].to(self.device)
            id_z = batch[3]
            famhot=batch[4]
            self.optim.zero_grad()  
            y_tr = self.forward(x,id_z,famhot)
        
            loss = self.loss_func(y_tr,y)
            f1 = get_f1(y.cpu(), y_tr.detach().cpu(), batch[2])
            avg_f1 += f1
            avg_loss += loss
            loss.backward() 
            self.optim.step()
            train_step+=1

        avg_f1 /= len(data_loader)
        avg_loss /= len(data_loader)
        return avg_loss,avg_f1
    def tst(self,data_loader):
        self.eval() 
        avg_loss=0
        avg_f1=0
        test_step = 0
        #desactivamos el gradiente por que no hacemos backward()
        with tr.no_grad():       
            for batch in data_loader:
                x = batch[0].to(self.device)
                y = batch[1].to(self.device)
                id_z = batch[3]
                famhot=batch[4]
                #por que aca y no desp
                y_tst = self.forward(x,id_z,famhot)
                # y_tst=tr.tensor([[x], *batch[2:]])
                loss = self.loss_func(y_tst,y)
                #.detach()?????????
                f1 = get_f1(y.cpu(), y_tst.detach().cpu(), batch[2])
                avg_loss += loss
                avg_f1 += f1
                test_step+=1
            avg_loss /= len(data_loader)
            avg_f1 /= len(data_loader)
            
            return avg_loss,avg_f1

# %% [markdown]
# # main

# %%
import torch as tr
from torch.utils.data import DataLoader, random_split
from dataset import DatasetSeq
maxlen=512
out_path = f"results/"
batch_size = 8
DEVICE = "cuda" 
dataset=DatasetSeq('data/archiveII_220808.csv',max_len=maxlen)
model = ignacioDist(kernel=11, device=DEVICE,max_len=maxlen,lr=1e-2,offset=9) 
secdist = pd.read_csv('data/SequenceIdentity_f_all.csv')
model.load_state_dict(tr.load(f"{out_path}model_onehot.pmt"))
print('entra a hacer las particiones')


n_train = int(0.8 * len(dataset))
n_test = int(0.1 * len(dataset))
n_val = len(dataset) - n_train - n_test



train_data, val_data, test_data = random_split(dataset, [n_train, n_val, n_test], generator=tr.Generator().manual_seed(42))
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False)

print("train batches", len(train_loader))
print("val batches", len(val_loader))
print("test batches", len(test_loader))
best_f1, patience_counter = 0, 0
for epoch in range(100):
    train_loss,train_f1 = model.tr(train_loader)
    print(f'train loop epoch {epoch}')
    val_loss,val_f1 = model.tst(val_loader)
    if val_f1 > best_f1:
        best_f1 = val_f1
        best_epoch = epoch
        tr.save(model.state_dict(), f"{out_path}model_onehot.pmt")
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter>50:
            break
    print(f"epoch {epoch}: train loss {train_loss:.2f} val loss {val_loss:.2f} train f1 {train_f1:.2f} val f1 {val_f1:.2f}")
print("Start test")
model.load_state_dict(tr.load(f"{out_path}model_onehot.pmt"))
test_loss, test_f1 = model.tst(test_loader)
print(f"best epoch {best_epoch} best_valf1 {best_f1:.3f} test_loss {test_loss:.3f} test_f1 {test_f1:.3f}")
# Out:
# entra a hacer las particiones
# train batches 387
# val batches 49
# test batches 49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 31
#      29 best_f1, patience_counter = 0, 0
#      30 for epoch in range(100):
# ---> 31     train_loss,train_f1 = model.tr(train_loader)
#      32     print(f'train loop epoch {epoch}')
#      33     val_loss,val_f1 = model.tst(val_loader)
#
# Cell In[7], line 137, in ignacioDist.tr(self, data_loader)
#     134 y_tr = self.forward(x,id_z,famhot)
#     136 loss = self.loss_func(y_tr,y)
# --> 137 f1 = get_f1(y.cpu(), y_tr.detach().cpu(), batch[2])
#     138 avg_f1 += f1
#     139 avg_loss += loss
#
# Cell In[5], line 17, in get_f1(ref_batch, predict_batch, L, th)
#      15     ref = ref[ind[0], ind[1]].numpy().ravel()
#      16     predict = predict[ind[0], ind[1]].numpy().ravel()
# ---> 17     f1.append(f1_score(ref, predict, zero_division=1))
#      18 return tr.tensor(f1).mean()
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1146, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1011 def f1_score(
#    1012     y_true,
#    1013     y_pred,
#    (...)
#    1019     zero_division="warn",
#    1020 ):
#    1021     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1022
#    1023     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1144     array([0.66666667, 1.        , 0.66666667])
#    1145     """
# -> 1146     return fbeta_score(
#    1147         y_true,
#    1148         y_pred,
#    1149         beta=1,
#    1150         labels=labels,
#    1151         pos_label=pos_label,
#    1152         average=average,
#    1153         sample_weight=sample_weight,
#    1154         zero_division=zero_division,
#    1155     )
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1287, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1158 def fbeta_score(
#    1159     y_true,
#    1160     y_pred,
#    (...)
#    1167     zero_division="warn",
#    1168 ):
#    1169     """Compute the F-beta score.
#    1170
#    1171     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1284     array([0.71..., 0.        , 0.        ])
#    1285     """
# -> 1287     _, _, f, _ = precision_recall_fscore_support(
#    1288         y_true,
#    1289         y_pred,
#    1290         beta=beta,
#    1291         labels=labels,
#    1292         pos_label=pos_label,
#    1293         average=average,
#    1294         warn_for=("f-score",),
#    1295         sample_weight=sample_weight,
#    1296         zero_division=zero_division,
#    1297     )
#    1298     return f
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1577, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
# -> 1577 MCM = multilabel_confusion_matrix(
#    1578     y_true,
#    1579     y_pred,
#    1580     sample_weight=sample_weight,
#    1581     labels=labels,
#    1582     samplewise=samplewise,
#    1583 )
#    1584 tp_sum = MCM[:, 1, 1]
#    1585 pred_sum = tp_sum + MCM[:, 0, 1]
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/metrics/_classification.py:497, in multilabel_confusion_matrix(y_true, y_pred, sample_weight, labels, samplewise)
#     494 if y_type not in ("binary", "multiclass", "multilabel-indicator"):
#     495     raise ValueError("%s is not supported" % y_type)
# --> 497 present_labels = unique_labels(y_true, y_pred)
#     498 if labels is None:
#     499     labels = present_labels
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/utils/multiclass.py:114, in unique_labels(*ys)
#     111     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#     112     return xp.unique_values(unique_ys)
# --> 114 ys_labels = set(chain.from_iterable((i for i in _unique_labels(y)) for y in ys))
#     115 # Check that we don't mix string type with number type
#     116 if len(set(isinstance(label, str) for label in ys_labels)) > 1:
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/utils/multiclass.py:114, in <genexpr>(.0)
#     111     unique_ys = xp.concat([_unique_labels(y) for y in ys])
#     112     return xp.unique_values(unique_ys)
# --> 114 ys_labels = set(chain.from_iterable((i for i in _unique_labels(y)) for y in ys))
#     115 # Check that we don't mix string type with number type
#     116 if len(set(isinstance(label, str) for label in ys_labels)) > 1:
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/utils/multiclass.py:26, in _unique_multiclass(y)
#      24 xp, is_array_api = get_namespace(y)
#      25 if hasattr(y, "__array__") or is_array_api:
# ---> 26     return xp.unique_values(xp.asarray(y))
#      27 else:
#      28     return set(y)
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/sklearn/utils/_array_api.py:84, in _NumPyApiWrapper.unique_values(self, x)
#      83 def unique_values(self, x):
# ---> 84     return numpy.unique(x)
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/numpy/lib/arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     272 ar = np.asanyarray(ar)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#     278 # axis was specified and not None
#
# File ~/CientiBeca_rna/enviroments/env_rna/lib/python3.8/site-packages/numpy/lib/arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     334     aux = ar[perm]
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#     338 mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %%
print("Start test")
model.load_state_dict(tr.load(f"{out_path}model_onehot.pmt"))
test_loss, test_f1 = model.tst(test_loader)
print(f"best epoch {best_epoch} best_valf1 {best_f1:.3f} test_loss {test_loss:.3f} test_f1 {test_f1:.3f}")
# Out:
# Start test
# best epoch 3 best_valf1 0.712 test_loss 0.079 test_f1 0.673

# %% [markdown]
#  nvidia-smi -l 5
